# %% [markdown]
# Import Libraries
#
# All libraries are used for specific tasks including data preprocessing, visualization, transformation and evaluation

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Import Data
#
# Read Training Data

# %%
dataTrain=pd.read_csv('Sales.csv')

dataTrain.head()
# Out:
#     Brands        Models         Colors Memory Storage Camera  Rating  \
# 0  SAMSUNG  GALAXY M31S    Mirage Black   8 GB  128 GB    Yes     4.3
# 1    Nokia           3.2          Steel   2 GB   16 GB    Yes     3.8
# 2   realme           C2   Diamond Black   2 GB     NaN    Yes     4.4
# 3  Infinix        Note 5       Ice Blue   4 GB   64 GB    Yes     4.2
# 4    Apple    iPhone 11           Black    4GB   64 GB    Yes     4.6
#
#                  Mobile  Discount  discount percentage  Original Price  \
# 0  SAMSUNG GALAXY M31S       1669             7.947998           20999
# 1             Nokia 3.2         0             0.000000           10199
# 2            realme C2       1000            12.501563            7999
# 3        Infinix Note 5         0             0.000000           12999
# 4      Apple iPhone 11          0             0.000000           49900
#
#    Selling Price
# 0          19330
# 1          10199
# 2           6999
# 3          12999
# 4          49900

# %%
dataTrain.shape
# Out:
# (3114, 12)

# %%
dataTrain.columns #to know the column names
# Out:
# Index(['Brands', 'Models', 'Colors', 'Memory', 'Storage', 'Camera', 'Rating',
#        'Mobile', 'Discount', 'discount percentage', 'Original Price',
#        'Selling Price'],
#       dtype='object')

# %%
dataTrain['Brands'].unique() #to know the unique Brands
# Out:
# array(['SAMSUNG', 'Nokia', 'realme', 'Infinix', 'Apple', 'GIONEE',
#        'Xiaomi', 'OPPO', 'vivo', 'Lenovo', 'ASUS', 'Motorola', 'HTC',
#        'Google Pixel', 'LG', 'POCO', 'IQOO'], dtype=object)

# %%
dataTrain['Brands'].value_counts() #to know the count of each Brands
# Out:
# Brands
# SAMSUNG         719
# Apple           387
# realme          327
# OPPO            260
# Nokia           213
# Xiaomi          198
# Infinix         151
# GIONEE          129
# vivo            124
# Lenovo          121
# ASUS            118
# Motorola        105
# LG               99
# POCO             74
# HTC              55
# Google Pixel     29
# IQOO              5
# Name: count, dtype: int64

# %%
dataTrain.isnull().sum()
# Out:
# Brands                   0
# Models                   0
# Colors                   0
# Memory                  43
# Storage                 39
# Camera                   0
# Rating                 144
# Mobile                   0
# Discount                 0
# discount percentage      0
# Original Price           0
# Selling Price            0
# dtype: int64

# %%
dataTrain=dataTrain.dropna()

# %%
dataTrain.isnull().sum()
# Out:
# Brands                 0
# Models                 0
# Colors                 0
# Memory                 0
# Storage                0
# Camera                 0
# Rating                 0
# Mobile                 0
# Discount               0
# discount percentage    0
# Original Price         0
# Selling Price          0
# dtype: int64

# %%
dataTrain.shape
# Out:
# (2897, 12)

# %%
dataTrain.dtypes
# Out:
# Brands                  object
# Models                  object
# Colors                  object
# Memory                  object
# Storage                 object
# Camera                  object
# Rating                 float64
# Mobile                  object
# Discount                 int64
# discount percentage    float64
# Original Price           int64
# Selling Price            int64
# dtype: object

# %%
plt.figure(figsize=(10,6))
numerical_features = dataTrain.select_dtypes(include=['number']).columns
corr = dataTrain[numerical_features].corr()
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# From the heatmap, it is observed that Some features, like Rating and Discount  with Selling price, show very weak correlations (close to zero), indicating minimal linear relationships.

# %% [markdown]
# Regression/scatter Plot

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Discount", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Discount', ylabel='Selling Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Discount'], dataTrain['Selling Price']) # Changed stats.pr to stats.pearsonr and daearsontaTrain to dataTrain
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.24882195493806603  with a P-value of P = 3.9380850615915904e-42

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Original Price", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Original Price', ylabel='Selling Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Original Price'], dataTrain['Selling Price']) # Changed stats.pr to stats.pearsonr and daearsontaTrain to dataTrain
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9820263570107177  with a P-value of P = 0.0

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Rating", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Rating', ylabel='Selling Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Rating'], dataTrain['Selling Price']) # Changed stats.pr to stats.pearsonr and daearsontaTrain to dataTrain
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.45887608534097696  with a P-value of P = 7.4555127559895e-151

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="discount percentage", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='discount percentage', ylabel='Selling Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['discount percentage'], dataTrain['Selling Price']) # Changed stats.pr to stats.pearsonr and daearsontaTrain to dataTrain
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.03612556827053197  with a P-value of P = 0.051870094074544126

# %%
sns.boxplot(x="Models", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Models', ylabel='Selling Price'>

# %%
sns.boxplot(x="Colors", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Colors', ylabel='Selling Price'>

# %%
sns.boxplot(x="Memory", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Memory', ylabel='Selling Price'>

# %%
sns.boxplot(x="Storage", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Storage', ylabel='Selling Price'>

# %%
sns.boxplot(x="Camera", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Camera', ylabel='Selling Price'>

# %%
sns.boxplot(x="Mobile", y="Selling Price", data=dataTrain)
# Out:
# <Axes: xlabel='Mobile', ylabel='Selling Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Brands", y="Selling Price", data=dataTrain, palette="husl")
# Out:
# <Axes: xlabel='Brands', ylabel='Selling Price'>

# %%
dataTrain.drop(['Camera'], axis = 1, inplace = True)

# %%
column_names = dataTrain.columns.tolist()
column_names
# Out:
# ['Brands',
#  'Models',
#  'Colors',
#  'Memory',
#  'Storage',
#  'Rating',
#  'Mobile',
#  'Discount',
#  'discount percentage',
#  'Original Price',
#  'Selling Price']

# %%
feature_column_names = dataTrain.drop(['Selling Price'], axis = 1).columns.tolist()
feature_column_names
# Out:
# ['Brands',
#  'Models',
#  'Colors',
#  'Memory',
#  'Storage',
#  'Rating',
#  'Mobile',
#  'Discount',
#  'discount percentage',
#  'Original Price']

# %%
dataTrain.shape
# Out:
# (2897, 11)

# %%
dataTrain.describe()
# Out:
#             Rating      Discount  discount percentage  Original Price  \
# count  2897.000000   2897.000000          2897.000000     2897.000000
# mean      4.241319   1964.185709             6.222417    26656.677943
# std       0.272841   5505.394873            11.353050    28251.233298
# min       2.300000  -8000.000000          -160.320641     1000.000000
# 25%       4.100000      0.000000             0.000000    10389.000000
# 50%       4.300000      0.000000             0.000000    16300.000000
# 75%       4.400000   2000.000000             9.836388    29999.000000
# max       5.000000  75000.000000            70.610305   189999.000000
#
#        Selling Price
# count    2897.000000
# mean    24692.492233
# std     26373.592602
# min      1000.000000
# 25%      9990.000000
# 50%     14999.000000
# 75%     27499.000000
# max    179900.000000

# %%
# delete all rows with column 'Selling Price' has value <100
price = dataTrain[ (dataTrain['Selling Price'] < 100.00)  ].index
dataTrain.drop(price, inplace = True)

# %%
dataTrain.shape
# Out:
# (2897, 11)

# %%
#This is a check for categorical data
dataTrain.describe(include=['object'])
# Out:
#          Brands      Models Colors Memory Storage            Mobile
# count      2897        2897   2897   2897    2897              2897
# unique       17         877    622     24      25               891
# top     SAMSUNG  iPhone 11   Black   4 GB   64 GB  Apple iPhone 11
# freq        685          36    446    711     757                36

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataTrain.Brands = labelencoder.fit_transform(dataTrain.Brands)
dataTrain.Models = labelencoder.fit_transform(dataTrain.Models)
dataTrain.Colors = labelencoder.fit_transform(dataTrain.Colors)
dataTrain.Memory = labelencoder.fit_transform(dataTrain.Memory)

dataTrain.Storage = labelencoder.fit_transform(dataTrain.Storage)
dataTrain.Mobile = labelencoder.fit_transform(dataTrain.Mobile)

# %%
dataTrain.head(10)
# Out:
#     Brands  Models  Colors  Memory  Storage  Rating  Mobile  Discount  \
# 0       13     274     349      22        3     4.3     529      1669
# 1       10      44     546       9        9     3.8     398         0
# 3        6     560     266      14       19     4.2     174         0
# 4        1     854      45      17       19     4.6      29         0
# 5        2     484      45      23       10     4.0      75         0
# 7        1     874     134      11       19     4.6      49      4901
# 8       13     325      85       1        9     4.2     577         0
# 9       14     633      15      22        3     4.3     758      1263
# 10      13     283      45      14       19     4.2     535         0
# 11       1     854     471      17       12     4.6      29         0
#
#     discount percentage  Original Price  Selling Price
# 0              7.947998           20999          19330
# 1              0.000000           10199          10199
# ...

# %%
#values before data transformation
x_train_actual=dataTrain.iloc[:,0:11]
y_train_actual=dataTrain.iloc[:, -1]  # Select the last column using -1

# %%
# Calculate the z-score from with scipy #ideally the values range from -1 to 1

import scipy.stats as stats
dataTrain = stats.zscore(dataTrain)

# %%
dataTrain
# Out:
#         Brands    Models    Colors    Memory   Storage    Rating    Mobile  \
# 0     0.702088 -0.674973  0.319420  1.461415 -1.443451  0.215113  0.333302
# 1     0.102810 -1.527685  1.322551 -0.770744 -0.503466 -1.617775 -0.147522
# 3    -0.696227  0.385355 -0.103219  0.087779  1.063174 -0.151465 -0.969695
# 4    -1.695024  1.475343 -1.228559  0.602892  1.063174  1.314845 -1.501905
# 5    -1.495264  0.103590 -1.228559  1.633119 -0.346802 -0.884620 -1.333066
# ...        ...       ...       ...       ...       ...       ...       ...
# 3107  0.702088 -0.196713 -1.228559  0.774597  0.436518 -0.884620  0.795774
# 3108  0.702088  0.237057 -1.228559  0.259483 -0.190138 -0.151465  0.975625
# 3109  0.502329  0.177738 -0.805920  0.946301 -1.443451  0.581690  0.311280
# 3111 -1.695024  1.542077  1.648442 -0.770744 -1.443451  0.948268 -1.435838
# 3113 -1.495264 -0.812148 -1.121626 -0.427335  0.279854 -0.151465 -1.347748
#
#       Discount  discount percentage  Original Price  Selling Price
# ...

# %%
#In case the value is outside this range, may indicate potential outliers
#resulting in impacting model predictions.
#Since outliers had been dealt earlier, so just clipping the value

#it was observed that clipping the values to this range affects the performance (however postitively)
dataTrain = dataTrain.clip(-1, 1)

# %%
x_train=dataTrain.iloc[:,0:10]
y_train=dataTrain.iloc[:,-1]

# %%
x_train.head()
# Out:
#      Brands    Models    Colors    Memory   Storage    Rating    Mobile  \
# 0  0.702088 -0.674973  0.319420  1.000000 -1.000000  0.215113  0.333302
# 1  0.102810 -1.000000  1.000000 -0.770744 -0.503466 -1.000000 -0.147522
# 3 -0.696227  0.385355 -0.103219  0.087779  1.000000 -0.151465 -0.969695
# 4 -1.000000  1.000000 -1.000000  0.602892  1.000000  1.000000 -1.000000
# 5 -1.000000  0.103590 -1.000000  1.000000 -0.346802 -0.884620 -1.000000
#
#    Discount  discount percentage  Original Price
# 0 -0.053627             0.152019       -0.200298
# 1 -0.356836            -0.548178       -0.582648
# 3 -0.356836            -0.548178       -0.483520
# 4 -0.356836            -0.548178        0.822879
# 5 -0.356836            -0.548178       -0.865870

# %%
y_train.head()
# Out:
# 0   -0.203363
# 1   -0.549640
# 3   -0.443455
# 4    0.955951
# 5   -0.853027
# Name: Selling Price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# Assuming X and y are your features and target variable respectively
# Replace X and y with your actual feature and target variable names
X_train, X_test, y_train, y_test = train_test_split(x_train, y_train, train_size=0.7, random_state=42)

# %% [markdown]
# Fit Model
#
# Multiple Linear Regression

# %%
model = LinearRegression()
# Use the training subsets (X_train, y_train) to fit the model
model_mlr = model.fit(X_train, y_train)

# %%
y_pred_MLR = model_mlr.predict(X_test) # Use X_test instead of x_test

# %% [markdown]
# MLR Evaluation

# %%
mse1 = mean_squared_error(y_test, y_pred_MLR)
print('The mean square error for Multiple Linear Regression: ', mse1)
# Out:
# The mean square error for Multiple Linear Regression:  0.0040113664744308025

# %%
mae1= mean_absolute_error(y_test, y_pred_MLR)
print('The mean absolute error for Multiple Linear Regression: ', mae1)
# Out:
# The mean absolute error for Multiple Linear Regression:  0.026981964181042525

# %% [markdown]
# Random Forest Regressor

# %%
rf = RandomForestRegressor()
model_rf = rf.fit(X_train, y_train) # Use X_train and y_train from train_test_split

# %%
y_pred_RF = model_rf.predict(X_test) # Use X_test instead of x_test

# %% [markdown]
# Random Forest Evaluation

# %%
mse2 = mean_squared_error(y_test, y_pred_RF)
print('The mean square error of price and predicted value is: ', mse2)
# Out:
# The mean square error of price and predicted value is:  0.0015044142733957988

# %%
mae2= mean_absolute_error(y_test, y_pred_RF)
print('The mean absolute error of price and predicted value is: ', mae2)
# Out:
# The mean absolute error of price and predicted value is:  0.008298504022601568

# %% [markdown]
# LASSO Model

# %%
LassoModel = Lasso()
# Use X_train and y_train from train_test_split, not x_train and y_train
model_lm = LassoModel.fit(X_train, y_train)

# %%
y_pred_LSO = model_lm.predict(X_test)

# %% [markdown]
# LASSO Evaluation
#
# Mean Absolute Error for LASSO Model

# %%
mae3= mean_absolute_error(y_test, y_pred_LSO)
print('The mean absolute error of price and predicted value is: ', mae3)
# Out:
# The mean absolute error of price and predicted value is:  0.4694410647029973

# %% [markdown]
# Mean Squared Error for the LASSO Model

# %%
mse3 = mean_squared_error(y_test, y_pred_LSO)
print('The mean square error of price and predicted value is: ', mse3)
# Out:
# The mean square error of price and predicted value is:  0.3257011708477613

# %%
scores = [('MLR', mae1),
          ('Random Forest', mae2),
          ('LASSO', mae3)
         ]

# %%
mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
mae
# Out:
#            Model  MAE Score
# 0            MLR   0.026982
# 1  Random Forest   0.008299
# 2          LASSO   0.469441

# %%
mae.sort_values(by=(['MAE Score']), ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(10,7))

model_colors = ['red', 'blue', 'green']

sns.barplot(x = mae['Model'], y=mae['MAE Score'], ax = axe, palette=model_colors)

axe.set_xlabel('Model', size=20)
axe.set_ylabel('Mean Absolute Error', size=20)

plt.show()
